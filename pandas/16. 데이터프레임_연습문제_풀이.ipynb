# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# %%
df = pd.read_csv('data/births.txt',header=None,
            index_col=0)
df.columns=['남아수','여아수']
df.index.name ='년도'
df
# Out:
#           남아수      여아수
# 년도
# 1880    90993   110491
# 1881    91954   100745
# 1882   107850   113688
# 1883   112321   104629
# 1884   129022   114445
# ...       ...      ...
# 2007  1919408  2072139
# 2008  1887234  2036289
# 2009  1832925  1979303
# 2010  1772738  1913851
# 2011  1753500  1893230
#
# [132 rows x 2 columns]

# %%
1.남아수 총합을 구하시요
2.여아수 평균을 구하시요
3.남아수가 가장많은 년도와
남아수를 구하시요
4.2000년도 이후 데이터를
구하시요
5. 1995~ 2000 년도 데이터를
구하시요

# %%
df['남아수'].sum()
# Out:
# 161802441

# %%
round( df['여아수'].mean() ,2 )
# Out:
# 1245399.21

# %%
round(3.141592,2)
# Out:
# 3.14

# %%
# 3.남아수가 가장많은 년도와남아수를 구하시요
mx = df['남아수'].max()
# df['남아수'].idxmax()
# df[ df['남아수']==mx ][ ['남아수']]
df.query( f'남아수=={mx}')['남아수']
# Out:
# 년도
# 1957    2044160
# Name: 남아수, dtype: int64

# %%
# 4.2000년도 이후 데이터를구하시요
df.loc[2000:]
# Out:
#           남아수      여아수
# 년도
# 2000  1814601  1962406
# 2001  1799049  1941251
# 2002  1795206  1939815
# 2003  1825359  1973434
# 2004  1834145  1982794
# 2005  1845379  1994841
# 2006  1898463  2052377
# 2007  1919408  2072139
# 2008  1887234  2036289
# 2009  1832925  1979303
# 2010  1772738  1913851
# 2011  1753500  1893230

# %%
# 5. 1995~ 2000 년도 데이터를구하시요
df.loc[1995:2000]
# Out:
#           남아수      여아수
# 년도
# 1995  1757927  1902832
# 1996  1752249  1893378
# 1997  1739806  1884122
# 1998  1765915  1910250
# 1999  1772632  1918809
# 2000  1814601  1962406

# %%
6. 남아출생이 가장많은 top5
를 구하시요(년도와 남아수)
7. 남아율(%) 컬럼을 추가하고 각년도별
남아수가 차지하는비율을 데이터로
보여주시요.
8. 2000년도 이후데이터 에 대해
출생량 컬럼을 추가하고
남아수가 1800000 이상이면 '많음'아니면 '적음'
이라고 보여 주시요
	남아수 출생량
2000   1233   '많음'
2001   1234   '적음'
9.1800년대,1900년대,2000년대 
각 남아,여야수 평균을 구하시요

# %%
# 6. 남아출생이 가장많은 top5
# 를 구하시요(년도와 남아수)

# %%
# df['남아수'].nlargest()
df.nlargest(5, '남아수')['남아수']
# Out:
# 년도
# 1957    2044160
# 1959    2023044
# 1960    2022093
# 1961    2017316
# 1958    2010884
# Name: 남아수, dtype: int64

# %%
7. 남아율(%) 컬럼을 추가하고 각년도별
남아수가 차지하는비율을 데이터로
보여주시요.

# %%
pd.set_option('display.max_rows', len(df))
# pd.set_option('display.max_columns', 갯수)

# %%
df['남아율'] = df['남아수']/ (df['남아수']+df['여아수'])
df
# Out:
#           남아수      여아수       남아율
# 년도
# 1880    90993   110491  0.451614
# 1881    91954   100745  0.477190
# 1882   107850   113688  0.486824
# 1883   112321   104629  0.517728
# 1884   129022   114445  0.529936
# 1885   133055   107800  0.552428
# 1886   144535   110784  0.566096
# 1887   145982   101414  0.590074
# 1888   178627   120853  0.596457
# 1889   178366   110584  0.617290
# 1890   190377   111025  0.631638
# 1891   185482   101196  0.647005
# 1892   212346   122037  0.635038
# 1893   212906   112317  0.654646
# 1894   222922   115772  0.658181
# 1895   233630   117398  0.665559
# 1896   237920   119570  0.665529
# 1897   234202   112758  0.675012
# 1898   258770   122693  0.678362
# 1899   233023   106212  0.686907
# 1900   299828   150499  0.665801
# 1901   239348   106471  0.692119
# 1902   264077   122659  0.682835
# 1903   261973   119234  0.687220
# 1904   275371   128125  0.682463
# 1905   291629   132319  0.687889
# 1906   295303   133159  0.689216
# ...

# %%
# 8. 2000년도 이후데이터 에 대해
# 출생량 컬럼을 추가하고
# 남아수가 1800000 이상이면 '많음'아니면 '적음'
# 이라고 보여 주시요
# 	남아수 출생량
# 2000   1233   '많음'
# 2001   1234   '적음'

# %%
import warnings
warnings.simplefilter('ignore')

# %%
y2000 = df.loc[2000:]
y2000['출생량'] = y2000['남아수'].apply( lambda v: '많음' if v>=1800000 else '적음')
y2000
# Out:
#           남아수      여아수       남아율 출생량
# 년도
# 2000  1814601  1962406  0.480434  많음
# 2001  1799049  1941251  0.480991  적음
# 2002  1795206  1939815  0.480641  적음
# 2003  1825359  1973434  0.480510  많음
# 2004  1834145  1982794  0.480528  많음
# 2005  1845379  1994841  0.480540  많음
# 2006  1898463  2052377  0.480521  많음
# 2007  1919408  2072139  0.480868  많음
# 2008  1887234  2036289  0.481005  많음
# 2009  1832925  1979303  0.480802  많음
# 2010  1772738  1913851  0.480861  적음
# 2011  1753500  1893230  0.480842  적음

# %%
df.drop(columns=['남아율'],inplace=True)

# %%
# 9.1800년대,1900년대,2000년대 각 남아,여야수 평균을 구하시요
y1800 = df.loc[1800:1899]
y1900 = df.loc[1900:1999]
y2000 = df.loc[2000:]
# print( y1800.mean() )
# print( y1900.mean() )
# print( y2000.mean() )
# df.loc[1800:1899].mean()
df2 = pd.DataFrame([y1800.mean(),y1900.mean(),y2000.mean()])
df2.index = ['1800년대','1900년대','2000년대']
df2.index.name ='평균값'
df2 = df2.round(2)
df2
# Out:
#                남아수         여아수
# 평균값
# 1800년대   176714.15   111820.55
# 1900년대  1362901.51  1384145.55
# 2000년대  1831500.58  1978477.50

# %%
df2.T
# Out:
# 평균값     1800년대      1900년대      2000년대
# 남아수  176714.15  1362901.51  1831500.58
# 여아수  111820.55  1384145.55  1978477.50
